# %%
from utils import *

ids=get_uniprot_ids(['huri','humap'])
# Out:
# huri
# pair name HuRI found and ignored
# pair name - found and ignored
# pair name out found and ignored
# humap

# %%
find_pairs('283450')

# %%
ids
# Out:
# {'283450',
#  'Q16773',
#  'Q9UM63',
#  'Q9UGB7',
#  'Q96G03',
#  'Q92569',
#  'P55199',
#  'O43903',
#  'Q99873',
#  'Q9NPF7',
#  'Q5TAP6',
#  'P23141',
#  'A0A590UJJ6',
#  'Q04724',
#  'P05556',
#  'Q99525',
#  'O75157',
#  'Q13243',
#  'Q7Z4H9',
#  'O60258',
#  'Q7Z6J9',
#  'Q9UI36',
#  'Q9Y4F3',
#  'Q13901',
#  'Q13352',
#  'Q9Y3C4',
#  'Q92851',
#  'Q9UKV3',
#  'Q8N5M9',
#  'P10398',
#  'Q7Z7H5',
#  'Q9NWN3',
#  'Q9Y2R9',
#  'Q86XE0',
#  'Q96C36',
#  'Q8N4M1',
#  'Q96C11',
#  'sp|P18465|1B57_HUMAN',
#  'P09497',
#  'Q8IVV7',
#  'Q8NDB6',
#  'Q9UHD4',
#  'P31937',
#  'Q9BTT0',
#  'Q9Y4E1',
#  'Q9Y5A7',
#  'Q9UKY0',
#  'Q15349',
#  'P62891',
#  'A6NKD9',
#  'A0A1B0GU61',
#  'O15085',
#  'Q6P9F7',
#  'Q8IZD4',
#  'Q9H0N5',
#  'P48637',
#  'C9JRZ8',
#  'Q6P1W5',
#  'Q9UKT9',
#  'O14910',
#  'Q9P1Y5',
#  'Q9BZJ0',
#  'Q16514',
#  'A6NNF4',
#  'Q9H9P5',
#  'Q96AA8',
#  'Q9UJ72',
#  'Q68D85',
#  'Q96PY6',
#  'P36508',
#  'Q9NYW8',
#  'P54252',
#  'Q9BT17',
#  'Q9H813',
#  'P60059',
# ...
