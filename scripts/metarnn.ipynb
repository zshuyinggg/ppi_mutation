# %%
chr1
# Out:
#          #chr  pos(1-based) ref alt aaref aaalt hg19_chr hg19_pos(1-based)  \
# 0           1         65565   A   C     M     L        1             65565
# 1           1         65565   A   G     M     V        1             65565
# 2           1         65565   A   T     M     L        1             65565
# 3           1         65566   T   A     M     K        1             65566
# 4           1         65566   T   C     M     T        1             65566
# ...       ...           ...  ..  ..   ...   ...      ...               ...
# 8538787     1     248918362   G   C     X     S        1         249212561
# 8538788     1     248918362   G   T     X     L        1         249212561
# 8538789     1     248918363   A   C     X     C        1         249212562
# 8538790     1     248918363   A   G     X     W        1         249212562
# 8538791     1     248918363   A   T     X     C        1         249212562
#
#                     Ensembl_transcriptid          MetaRNN_score
# ...
