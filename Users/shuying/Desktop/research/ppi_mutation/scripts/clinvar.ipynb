# %%
import pandas as pd

# %%
file = '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/Jan19.txt'
out='/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/criteria_above_discard_redundant_clinsig.txt'

# %%
with open(file,'r') as f:
    with open(out,'w') as f_out:
        line=f.readline()
        f_out.write('clinvar_id;review_status;clinical_sig;uniprot_kb;variant_type;hgvs_p;missense\n')
        while True:
            line=f.readline()

            if line.count(';')>6:
                discard_num=line.count(';')-6+3
                line_new=';'.join(line.split(';')[:3]+line.split(';')[discard_num:])
                print(set(line.split(';'))-set(line_new.split(';')),' is discarded')
                f_out.write(line_new)
            else:
                f_out.write(line)
            if not line:break
# Out:
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' risk factor'}  is discarded
# {' risk factor'}  is discarded
# {' risk factor'}  is discarded
# {' risk factor'}  is discarded
# {' risk factor'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' risk factor'}  is discarded
# {' association', ' risk factor'}  is discarded
# {' association'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' risk factor'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' risk factor'}  is discarded
# {' risk factor'}  is discarded
# {' risk factor'}  is discarded
# {' association'}  is discarded
# {' risk factor', ' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' other'}  is discarded
# {' risk factor'}  is discarded
# {' other'}  is discarded
# {' risk factor'}  is discarded
# {' risk factor'}  is discarded
# {' risk factor'}  is discarded
# {' association'}  is discarded
# {' risk factor'}  is discarded

# %% [markdown]
# # Inspect data

# %%
data=pd.read_csv(out,delimiter=';')
data.head()
# Out:
#      clinvar_id                        review_status  \
# 0  SCV002232601  criteria provided, single submitter
# 1  SCV002291827  criteria provided, single submitter
# 2  SCV001445903  criteria provided, single submitter
# 3  SCV001449002  criteria provided, single submitter
# 4  SCV000935565  criteria provided, single submitter
#
#                    clinical_sig         uniprot_kb variant_type  \
# 0                    Pathogenic  P04181#VAR_000578    Variation
# 1        Uncertain significance  P04181#VAR_015648    Variation
# 2             Likely pathogenic  P12955#VAR_011615    Variation
# 3  Pathogenic/Likely pathogenic  P12955#VAR_004405    Variation
# 4             Likely pathogenic  P21359#VAR_002663    Variation
#
#                 hgvs_p          missense
# 0   P04181:p.Arg271Lys  missense variant
# 1    P04181:p.Gln90Glu  missense variant
# 2   P12955:p.Gly278Asp  missense variant
# 3   P12955:p.Gly448Arg  missense variant
# 4  P21359:p.Leu1953Pro  missense variant

# %%
data.clinical_sig.unique()
# Out:
# array(['Pathogenic', 'Uncertain significance', 'Likely pathogenic',
#        'Pathogenic/Likely pathogenic', 'Benign', 'Likely benign',
#        'Conflicting interpretations of pathogenicity',
#        'Benign/Likely benign', 'drug response', 'other',
#        'Likely risk allele', 'risk factor',
#        'Pathogenic/Likely pathogenic/Established risk allele',
#        'Established risk allele', 'Pathogenic/Pathogenic, low penetrance',
#        'association'], dtype=object)

# %%
data.variant_type.unique()
# Out:
# array(['Variation', 'single nucleotide variant', 'copy number gain'],
#       dtype=object)

# %% [markdown]
# # Process clinical significance

# %% [markdown]
# ['Pathogenic', 'Uncertain significance', 'Likely pathogenic',
#        'Pathogenic/Likely pathogenic', 'Benign', 'Likely benign',
#        'Conflicting interpretations of pathogenicity',
#        'Benign/Likely benign', 'drug response', 'other',
#        'Likely risk allele', 'risk factor',
#        'Pathogenic/Likely pathogenic/Established risk allele',
#        'Established risk allele', 'Pathogenic/Pathogenic, low penetrance',
#        'association']

# %%
def if_positive_or_negative(string_list):
    label=[]
    for string in string_list:
        if string in ['Pathogenic', 
                    'Pathogenic/Likely pathogenic', 
                    'probable-pathogenic',
                    'Likely pathogenic', 
                    'pathologic', 
                    'pathogenic',
                    'likely pathogenic',
                    'Pathogenic/Likely pathogenic/Established risk allele',
                    'likely pathogenic - adrenal pheochromocytoma',
                    'Pathogenic/Pathogenic, low penetrance',
                    'Pathogenic, low penetrance']:
            label.append(1)
        elif string in ['Benign',
                    'Likely benign',
                    'Likely Benign',
                    'Benign/Likely benign',
                    'non-pathogenic', 
                    'benign', 'probable-non-pathogenic', 'Likely Benign', 'probably not pathogenic',
        ]:
            label.append(-1)

        else: label.append(0)
    return label

# %%
data['label']=if_positive_or_negative(data['clinical_sig'])

# %% [markdown]
# ## Generate Positive Clinvar File and Negative Clinvar File

# %%
data[data['label']==1].to_csv('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/clinvar_pos.csv',sep=';')
data[data['label']==-1].to_csv('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/clinvar_neg.csv',sep=';')

# %%
data[data['label']==-1]
# Out:
#          clinvar_id                        review_status   clinical_sig  \
# 19     SCV000361195  criteria provided, single submitter         Benign
# 21     SCV001325434  criteria provided, single submitter  Likely benign
# 55     SCV000451797  criteria provided, single submitter  Likely benign
# 58     SCV001136513  criteria provided, single submitter         Benign
# 79     SCV001138159  criteria provided, single submitter         Benign
# ...             ...                                  ...            ...
# 32189  SCV002738545  criteria provided, single submitter         Benign
# 32191  SCV002612763  criteria provided, single submitter         Benign
# 32192  SCV002613575  criteria provided, single submitter  Likely benign
# 32196  SCV002614959  criteria provided, single submitter         Benign
# 32200  SCV002618433  criteria provided, single submitter  Likely benign
#
#               uniprot_kb variant_type               hgvs_p          missense  \
# 19     P0C7Q2#VAR_044331    Variation    P0C7Q2:p.Ala69Ser  missense variant
# 21     O60393#VAR_036636    Variation   O60393:p.Arg355His  missense variant
# 55     Q9NRM0#VAR_065775    Variation   Q9NRM0:p.Arg198Cys  missense variant
# 58     Q9NP91#VAR_052068    Variation   Q9NP91:p.Thr199Met  missense variant
# 79     P15169#VAR_042415    Variation   P15169:p.Gly178Asp  missense variant
# ...                  ...          ...                  ...               ...
# 32189  P17813#VAR_014764    Variation   P17813:p.Asp366His  missense variant
# 32191  Q14896#VAR_074545    Variation  Q14896:p.Arg1138His  missense variant
# 32192  Q14896#VAR_020571    Variation   Q14896:p.Leu383Val  missense variant
# 32196  Q8TAB3#VAR_067489    Variation  Q8TAB3:p.Asn1134His  missense variant
# 32200  Q8WZ42#VAR_040089    Variation  Q8WZ42:p.Val1202Ala  missense variant
#
#        label
# 19        -1
# 21        -1
# 55        -1
# 58        -1
# 79        -1
# ...      ...
# 32189     -1
# 32191     -1
# 32192     -1
# 32196     -1
# 32200     -1
#
# [12563 rows x 8 columns]

# %%
def generate_example(start,end):
    with open('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/ClinVarFullRelease_2021-06.xml', 'r') as f_in:
        with open('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/example_'+str(start)+'_'+str(end)+'.xml','w') as f_out:
            line_count=0
            while True:
                line=f_in.readline()
                line_count+=1
                if line_count>start and line_count<end:
                    f_out.write(line)
                if line_count>end:
                    break

def find_line(content):
    with open('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/ClinVarFullRelease_2021-06.xml', 'r') as f_in:
            line_count=0

            while True:
                line=f_in.readline()
                line_count+=1

                if content in line:
                    print(line_count)
                    break

# %%
generate_example(45667191,45669191)

# %%
f.head()
# Out:
#    #AlleleID                       Type  \
# 0      15041                      Indel
# 1      15041                      Indel
# 2      15042                   Deletion
# 3      15042                   Deletion
# 4      15043  single nucleotide variant
#
#                                                 Name  GeneID GeneSymbol  \
# 0  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 1  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 2     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 3     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 4       NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)    9640     ZNF592
#
#       HGNC_ID    ClinicalSignificance  ClinSigSimple LastEvaluated  \
# 0  HGNC:22197              Pathogenic              1             -
# 1  HGNC:22197              Pathogenic              1             -
# 2  HGNC:22197              Pathogenic              1  Jun 29, 2010
# 3  HGNC:22197              Pathogenic              1  Jun 29, 2010
# 4  HGNC:28986  Uncertain significance              0  Jun 29, 2015
#
#    RS# (dbSNP)  ...                         ReviewStatus NumberSubmitters  \
# 0    397704705  ...  criteria provided, single submitter                2
# 1    397704705  ...  criteria provided, single submitter                2
# 2    397704709  ...       no assertion criteria provided                1
# 3    397704709  ...       no assertion criteria provided                1
# 4    150829393  ...       no assertion criteria provided                1
#
#   Guidelines TestedInGTR                                           OtherIDs  \
# 0          -           N                  ClinGen:CA215070,OMIM:613653.0001
# 1          -           N                  ClinGen:CA215070,OMIM:613653.0001
# 2          -           N                  ClinGen:CA215072,OMIM:613653.0002
# 3          -           N                  ClinGen:CA215072,OMIM:613653.0002
# 4          -           N  OMIM:613624.0001,ClinGen:CA210674,UniProtKB:Q9...
#
#   SubmitterCategories VariationID PositionVCF ReferenceAlleleVCF  \
# 0                   3           2     4820844               GGAT
# 1                   3           2     4781213               GGAT
# 2                   1           3     4827360    GCTGCTGGACCTGCC
# 3                   1           3     4787729    GCTGCTGGACCTGCC
# 4                   1           4    85342440                  G
#
#        AlternateAlleleVCF
# 0  TGCTGTAAACTGTAACTGTAAA
# 1  TGCTGTAAACTGTAACTGTAAA
# 2                       G
# 3                       G
# 4                       A
#
# [5 rows x 34 columns]

# %%
f.columns
# Out:
# Index(['#AlleleID', 'Type', 'Name', 'GeneID', 'GeneSymbol', 'HGNC_ID',
#        'ClinicalSignificance', 'ClinSigSimple', 'LastEvaluated', 'RS# (dbSNP)',
#        'nsv/esv (dbVar)', 'RCVaccession', 'PhenotypeIDS', 'PhenotypeList',
#        'Origin', 'OriginSimple', 'Assembly', 'ChromosomeAccession',
#        'Chromosome', 'Start', 'Stop', 'ReferenceAllele', 'AlternateAllele',
#        'Cytogenetic', 'ReviewStatus', 'NumberSubmitters', 'Guidelines',
#        'TestedInGTR', 'OtherIDs', 'SubmitterCategories', 'VariationID',
#        'PositionVCF', 'ReferenceAlleleVCF', 'AlternateAlleleVCF'],
#       dtype='object')

# %%
f.loc[:,['#AlleleID', 'Type', 'Name','ClinicalSignificance', 'ClinSigSimple', 'LastEvaluated','RCVaccession', 'PhenotypeIDS', 'PhenotypeList','Origin', 'OriginSimple', 'Assembly','ReviewStatus', 'NumberSubmitters', 'Guidelines' ]].head()
# Out:
#    #AlleleID                       Type  \
# 0      15041                      Indel
# 1      15041                      Indel
# 2      15042                   Deletion
# 3      15042                   Deletion
# 4      15043  single nucleotide variant
#
#                                                 Name    ClinicalSignificance  \
# 0  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...              Pathogenic
# 1  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...              Pathogenic
# 2     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)              Pathogenic
# 3     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)              Pathogenic
# 4       NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)  Uncertain significance
#
#    ClinSigSimple LastEvaluated  RCVaccession  \
# 0              1             -  RCV000000012
# 1              1             -  RCV000000012
# 2              1  Jun 29, 2010  RCV000000013
# 3              1  Jun 29, 2010  RCV000000013
# 4              0  Jun 29, 2015  RCV000000014
#
#                                         PhenotypeIDS  \
# 0  MONDO:MONDO:0013342,MedGen:C3150901,OMIM:61364...
# 1  MONDO:MONDO:0013342,MedGen:C3150901,OMIM:61364...
# 2  MONDO:MONDO:0013342,MedGen:C3150901,OMIM:61364...
# 3  MONDO:MONDO:0013342,MedGen:C3150901,OMIM:61364...
# 4  MONDO:MONDO:0033005,MedGen:C4551772,OMIM:25130...
#
#                       PhenotypeList            Origin OriginSimple Assembly  \
# 0  Hereditary spastic paraplegia 48  germline;unknown     germline   GRCh37
# 1  Hereditary spastic paraplegia 48  germline;unknown     germline   GRCh38
# 2  Hereditary spastic paraplegia 48          germline     germline   GRCh37
# 3  Hereditary spastic paraplegia 48          germline     germline   GRCh38
# 4         Galloway-Mowat syndrome 1          germline     germline   GRCh37
#
#                           ReviewStatus  NumberSubmitters Guidelines
# 0  criteria provided, single submitter                 2          -
# 1  criteria provided, single submitter                 2          -
# 2       no assertion criteria provided                 1          -
# 3       no assertion criteria provided                 1          -
# 4       no assertion criteria provided                 1          -

# %% [markdown]
# # Dealing with the variant summary file

# %%
import pandas as pd
f=pd.read_csv('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/variant_summary.txt',sep='\t')
# Out:
# /tmp/ipykernel_124161/2855674157.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   f=pd.read_csv('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/variant_summary.txt',sep='\t')

# %%
f.head()
# Out:
#    #AlleleID                       Type  \
# 0      15041                      Indel
# 1      15041                      Indel
# 2      15042                   Deletion
# 3      15042                   Deletion
# 4      15043  single nucleotide variant
#
#                                                 Name  GeneID GeneSymbol  \
# 0  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 1  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 2     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 3     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 4       NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)    9640     ZNF592
#
#       HGNC_ID    ClinicalSignificance  ClinSigSimple LastEvaluated  \
# 0  HGNC:22197              Pathogenic              1             -
# 1  HGNC:22197              Pathogenic              1             -
# 2  HGNC:22197              Pathogenic              1  Jun 29, 2010
# 3  HGNC:22197              Pathogenic              1  Jun 29, 2010
# 4  HGNC:28986  Uncertain significance              0  Jun 29, 2015
#
#    RS# (dbSNP)  ...                         ReviewStatus NumberSubmitters  \
# 0    397704705  ...  criteria provided, single submitter                2
# 1    397704705  ...  criteria provided, single submitter                2
# 2    397704709  ...       no assertion criteria provided                1
# 3    397704709  ...       no assertion criteria provided                1
# 4    150829393  ...       no assertion criteria provided                1
#
#   Guidelines TestedInGTR                                           OtherIDs  \
# 0          -           N                  ClinGen:CA215070,OMIM:613653.0001
# 1          -           N                  ClinGen:CA215070,OMIM:613653.0001
# 2          -           N                  ClinGen:CA215072,OMIM:613653.0002
# 3          -           N                  ClinGen:CA215072,OMIM:613653.0002
# 4          -           N  OMIM:613624.0001,ClinGen:CA210674,UniProtKB:Q9...
#
#   SubmitterCategories VariationID PositionVCF ReferenceAlleleVCF  \
# 0                   3           2     4820844               GGAT
# 1                   3           2     4781213               GGAT
# 2                   1           3     4827360    GCTGCTGGACCTGCC
# 3                   1           3     4787729    GCTGCTGGACCTGCC
# 4                   1           4    85342440                  G
#
#        AlternateAlleleVCF
# 0  TGCTGTAAACTGTAACTGTAAA
# 1  TGCTGTAAACTGTAACTGTAAA
# 2                       G
# 3                       G
# 4                       A
#
# [5 rows x 34 columns]

# %%
def if_positive_or_negative(string_list):
    label=[]
    for string in string_list:
        if string in ['Pathogenic', 
                    'Pathogenic/Likely pathogenic', 
                    'probable-pathogenic',
                    'Likely pathogenic', 
                    'pathologic', 
                    'pathogenic',
                    'likely pathogenic',
                    'Pathogenic/Likely pathogenic/Established risk allele',
                    'likely pathogenic - adrenal pheochromocytoma',
                    'Pathogenic/Pathogenic, low penetrance',
                    'Pathogenic, low penetrance']:
            label.append(1)
        elif string in ['Benign',
                    'Likely benign',
                    'Likely Benign',
                    'Benign/Likely benign',
                    'non-pathogenic', 
                    'benign', 'probable-non-pathogenic', 'Likely Benign', 'probably not pathogenic',
        ]:
            label.append(-1)

        else: label.append(0)
    return label
f['label']=if_positive_or_negative(f['ClinicalSignificance'])
keep_cols=['#AlleleID', 'Type', 'Name','label', 'ClinicalSignificance', 'ClinSigSimple', 'ReviewStatus', 'OtherIDs', 'LastEvaluated', 'RS# (dbSNP)',
       'nsv/esv (dbVar)', 'RCVaccession']
keep_conditions=(f['Type']=='single nucleotide variant') &\
              (['no assertion' not in item for item in f['ReviewStatus'].tolist()]) &\
               (['p' in item for item in f['Name'].tolist()]) &\
               (f['label']!=0)
f_simple=f[keep_conditions][keep_cols]
f_simple.head()
# Out:
#     #AlleleID                       Type  \
# 6       15044  single nucleotide variant
# 32      15058  single nucleotide variant
# 40      15062  single nucleotide variant
# 48      15066  single nucleotide variant
# 54      15069  single nucleotide variant
#
#                                               Name  label  \
# 6      NM_017547.4(FOXRED1):c.694C>T (p.Gln232Ter)      1
# 32         NM_000410.4(HFE):c.848A>C (p.Gln283Pro)      1
# 40      NM_020779.4(WDR35):c.2590G>A (p.Ala864Thr)      1
# 48  NM_001042472.3(ABHD12):c.1054C>T (p.Arg352Ter)      1
# 54       NM_138413.4(HOGA1):c.860G>T (p.Gly287Val)      1
#
#             ClinicalSignificance  ClinSigSimple  \
# 6                     Pathogenic              1
# 32                    Pathogenic              1
# 40             Likely pathogenic              1
# 48                    Pathogenic              1
# 54  Pathogenic/Likely pathogenic              1
#
#                                          ReviewStatus  \
# 6   criteria provided, multiple submitters, no con...
# 32                criteria provided, single submitter
# 40                criteria provided, single submitter
# 48  criteria provided, multiple submitters, no con...
# 54  criteria provided, multiple submitters, no con...
#
#                                              OtherIDs LastEvaluated  \
# 6                   ClinGen:CA113792,OMIM:613622.0001  Jun 28, 2022
# 32  ClinGen:CA280949,UniProtKB:Q30201#VAR_037304,O...  Sep 12, 2022
# 40  UniProtKB:Q9P2L0#VAR_064582,OMIM:613602.0004,C...  May 25, 2017
# 48                  ClinGen:CA113811,OMIM:613599.0004  Jan 05, 2022
# 54  ClinGen:CA113813,UniProtKB:Q86XE5#VAR_064036,O...  Oct 13, 2022
#
#     RS# (dbSNP) nsv/esv (dbVar)                            RCVaccession
# 6     267606829               -  RCV000000015|RCV000578659|RCV001194045
# 32    111033563               -               RCV000000036|RCV001050090
# 40    267607175               -               RCV000000040|RCV000508347
# 48    267606624               -               RCV000000044|RCV001208516
# 54    138207257               -               RCV000000047|RCV000798240

# %%
from tqdm import tqdm
import multiprocessing
num_processes = multiprocessing.cpu_count()
chunk_size = int(f_simple.shape[0]/num_processes)
global pbar
pbar = tqdm(total=len(f_simple))
f_simple['UniPort']=[0]*len(f_simple)
chunks = [f_simple.iloc[f_simple.index[i:i + chunk_size]] for i in range(0, f_simple.shape[0], chunk_size)]
def func(df):
    for idx in df.index:
        if 'UniProt' not in df.loc[idx,'OtherIDs']:
                df.loc[idx,'UniPort']=get_uniprot_from_name(f_simple.loc[idx,'Name'])
        pbar.update(1)
    return df
pool = multiprocessing.Pool(processes=num_processes)
result = pool.map(func, chunks)
# Out:
#   0%|          | 646/558616 [04:48<66:51:00,  2.32it/s]
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001191016.3
#   0%|          | 1007/558616 [07:28<33:30:49,  4.62it/s]
# Error Finding Refseq
#   0%|          | 1032/558616 [07:38<98:10:26,  1.58it/s]

# %%
f_simple.index
# Out:
# Int64Index([      6,      32,      40,      48,      54,      60,      62,
#                  64,      66,      70,
#             ...
#             4323230, 4323238, 4323259, 4323261, 4323285, 4323293, 4323305,
#             4323310, 4323312, 4323316],
#            dtype='int64', length=558616)

# %%
f_simple['UniProtID']=[get_uniprot_from_name(name) for name in f_simple['Name']]
# Out:
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001142446.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001142446.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001127255.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001127255.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001127255.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001127255.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001277059.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001277059.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001191016.3
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001191016.3
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_199451.3
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_199451.3
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001368067.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001368067.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001368067.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001368067.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001368067.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001368067.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001368067.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001368067.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001368067.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001368067.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_213655.5
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_213655.5
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_213655.5
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_213655.5
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_176806.4
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_176806.4
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NM_001164277.2
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NR_001566.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NR_001566.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NR_001566.1
# Error found in https://rest.uniprot.org/uniprotkb/search?query=NR_001566.1
# Error Finding Refseq
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/clinvar.ipynb Cell 28 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.125.185.12/home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/clinvar.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> f_simple['UniProtID']=[get_uniprot_from_name(name) for name in f_simple['Name']]
#
# /home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/clinvar.ipynb Cell 28 in <listcomp>(.0)
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.125.185.12/home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/clinvar.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> f_simple['UniProtID']=[get_uniprot_from_name(name) for name in f_simple['Name']]
#
# /home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/clinvar.ipynb Cell 28 in get_uniprot_from_name(name)
#      <a href='vscode-notebook-cell://ssh-remote%2B10.125.185.12/home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/clinvar.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> except:
#      <a href='vscode-notebook-cell://ssh-remote%2B10.125.185.12/home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/clinvar.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     print('Error Finding Refseq')
# ---> <a href='vscode-notebook-cell://ssh-remote%2B10.125.185.12/home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/clinvar.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> uniprot=find_fasta_refseq(refseq)
#      <a href='vscode-notebook-cell://ssh-remote%2B10.125.185.12/home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/clinvar.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> return uniprot
#
# UnboundLocalError: local variable 'refseq' referenced before assignment

# %%
f_simple=f_simple.drop_duplicates(subset=['#AlleleID'])

# %% [markdown]
# ### Map RefSeqID to Uniprot ID

# %%
import requests
import json
import re
def find_fasta_refseq(refseqID):
    url='https://rest.uniprot.org/uniprotkb/search?query=%s'%refseqID
    cnt=json.loads(requests.get(url).text)
    try:
        assert re.search('uniprot',cnt.get("results")[0].get("entryType"),re.IGNORECASE)
        return cnt["results"][0]['primaryAccession']
    except:
        print('Error found in '+url)
        return 'Error found in '+url

def get_uniprot_from_name(name):
    try:
        refseq=re.match(r'\S*?(?=[\(:])',name).group(0)
        uniprot=find_fasta_refseq(refseq)

    except:
        print('Error Finding Refseq')
        uniprot=find_fasta_refseq(refseq)
    return uniprot

# %% [markdown]
# ### Extract UniProt from OtherIDs

# %%
import re
def extract_uniprot(string):
    try: m=re.match(r'.*UniProtKB:([0-9A-Z].*)#.*',string).group(1)
    except AttributeError: 
        print(string)
        m='0'
    return m

# %% [markdown]
# ### Merge multiprocess files

# %%
import pandas as pd
import re
def merge(dir,prefix,out_name,compare=True):
    d={}
    import os
    f_list=os.listdir(dir)
    for f in f_list:
        print(f)
        proc,num=re.match(r'%s([0-9a-zA-Z]*)_([0-9a-zA-Z]*)_finished.csv'%prefix,f).group(1),\
        re.match(r'%s([0-9a-zA-Z]*)_([0-9a-zA-Z]*)_finished.csv'%prefix,f).group(2)
        if compare:
            if  d.get(proc) is None or int(num)> d.get(proc):
                d[proc]=int(num)
        else:
            d[proc]=num
    f_out_list=[]
    for key in d.keys():
        f_out_list.append(os.path.join(dir,'%s%s_%s_finished.csv'%(prefix,key,d[key])))
    print(f_out_list)
    dfs=[]
    for f in f_out_list:
        dfs.append(pd.read_csv(f,index_col='#AlleleID')
                )
    df_out=pd.concat(dfs)
    df_out.to_csv(out_name)

# %%
merge('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2','2022-2-round1_proc_','merged_2022_2.csv',False)
# Out:
# 2022-2-round1_proc_101605_5128_finished.csv
# 2022-2-round1_proc_1086723_5128_finished.csv
# 2022-2-round1_proc_1134089_5128_finished.csv
# 2022-2-round1_proc_1162009_5128_finished.csv
# 2022-2-round1_proc_1202281_5128_finished.csv
# 2022-2-round1_proc_1322629_5128_finished.csv
# 2022-2-round1_proc_1543645_5128_finished.csv
# 2022-2-round1_proc_1670622_5128_finished.csv
# 2022-2-round1_proc_183957_5128_finished.csv
# 2022-2-round1_proc_1880543_5128_finished.csv
# 2022-2-round1_proc_2083431_5000_finished.csv
# 2022-2-round1_proc_2083431_5128_finished.csv
# 2022-2-round1_proc_2332108_13_finished.csv
# 2022-2-round1_proc_253695_5128_finished.csv
# 2022-2-round1_proc_327311_5128_finished.csv
# 2022-2-round1_proc_39665_5128_finished.csv
# 2022-2-round1_proc_500469_5128_finished.csv
# 2022-2-round1_proc_599586_5128_finished.csv
# 2022-2-round1_proc_6_5128_finished.csv
# 2022-2-round1_proc_671051_5128_finished.csv
# 2022-2-round1_proc_792358_5128_finished.csv
# 2022-2-round1_proc_923200_5128_finished.csv
# ['/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_101605_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_1086723_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_1134089_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_1162009_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_1202281_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_1322629_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_1543645_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_1670622_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_183957_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_1880543_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_2083431_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_2332108_13_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_253695_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_327311_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_39665_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_500469_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_599586_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_6_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_671051_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_792358_5128_finished.csv', '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2022-2/2022-2-round1_proc_923200_5128_finished.csv']

# %%
def exlude_synonymous(name):
    #"NM_017813.5(BPNT2):c.228C>A (p.Arg76=)"
    return bool(re.match(r'.*(\(p\.[a-zA-Z0-9]*=\)).*',name))

f2023=pd.read_csv('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/merged_2023_2_26.csv',index_col='#AlleleID')
f2023=f2023[[not exlude_synonymous(name) for name in f2023.Name.tolist()]]
f2023.to_csv('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/merged_2023_2_26.csv')

# %%
import pandas as pd
f2023=pd.read_csv('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/merged_2023_2_26.csv',index_col='#AlleleID')
f2022=pd.read_csv('/home/grads/z/zshuying/Documents/shuying/ppi_mutation/scripts/merged_2022_2.csv',index_col='#AlleleID')
f2023_no_error=f2023[f2023['UniProt'].apply(lambda x: 'Error' not in x)]
f2022_no_error=f2022[f2022['UniProt'].apply(lambda x: 'Error' not in x)]

# %%
# len(f2022.index.unique()),len(f2023.index.unique()),len(set(f2023.index)-set(f2022.index))
diff_1star=set(f2023_no_error.index)-set(f2022_no_error.index)
diff_2star=set(f2023_2star_no_error.index)-set(f2022_2star_no_error.index)
print(f2023_no_error.loc[diff_1star]['label'].value_counts())
print(f2023_2star_no_error.loc[diff_2star]['label'].value_counts())
# Out:
# -1    146630
#  1     27375
# Name: label, dtype: int64
# -1    10686
#  1     8462
# Name: label, dtype: int64
# /tmp/ipykernel_108981/2630773320.py:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   print(f2023_no_error.loc[diff_1star]['label'].value_counts())
# /tmp/ipykernel_108981/2630773320.py:5: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   print(f2023_2star_no_error.loc[diff_2star]['label'].value_counts())

# %%
f2022_2star_no_error=f2022_no_error[['single' not in item for item in f2022_no_error['ReviewStatus'].tolist()]]
f2023_2star_no_error=f2023_no_error[['single' not in item for item in f2023_no_error['ReviewStatus'].tolist()]]
len(f2022_2star_no_error.index.unique()),len(f2023_2star_no_error.index.unique()),len(set(f2023_2star_no_error.index)-set(f2022_2star_no_error.index))
# Out:
# (33148, 51297, 19148)

# %%
f2022_2star_no_error.to_csv('clinvar_2starabove_2022_02.csv')
f2023_2star_no_error.to_csv('clinvar_2starabove_2023_03.csv')
f2023_no_error.to_csv('clinvar_1starabove_2023_02.csv')
f2022_no_error.to_csv('clinvar_1starabove_2022_02.csv')

# %%
l=[
    '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2023_02_26_round4/2023-2-round4_proc_1089410_11400_finished.csv',
    '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2023_02_26_round4/2023-2-round4_proc_already_done_finished.csv',
    '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2023_02_26_round4/2023-2-round5_proc_134664_96_finished.csv',
    '/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data/clinvar/2023_02_26_round4/2023-2-round5_proc_already_done_finished.csv'
]
dfs=[]
for f in l:
    dfs.append(pd.read_csv(f,index_col='#AlleleID'))
df=pd.concat(dfs,sort=True)

# %%
df.drop_duplicates(subset='#AlleleID',)

# %%
for idx in df_total.index:
    if 'UniProt' in df_total.loc[idx,'OtherIDs'] and df_total.loc[idx,'UniPort']=='0':
        df_total.loc[idx,'UniPort']=extract_uniprot(df_total.loc[idx,'OtherIDs'])
# Out:
# ClinGen:CA284849,UniProtKB/Swiss-Prot:VAR_003185,OMIM:602671.0001
# ClinGen:CA219309,UniProtKB/Swiss-Prot:VAR_007850,OMIM:602671.0003
# ClinGen:CA219358,UniProtKB/Swiss-Prot:VAR_016840,OMIM:602671.0013
# ClinGen:CA219275,UniProtKB/Swiss-Prot:VAR_025601,OMIM:602671.0015
# ClinGen:CA254415,UniProtKB/Swiss-Prot:VAR_001491,OMIM:601011.0001
# ClinGen:CA119650,UniProtKB/Swiss-Prot:VAR_001492,OMIM:601011.0002
# ClinGen:CA254421,UniProtKB/Swiss-Prot:VAR_001494,OMIM:601011.0004
# ClinGen:CA254430,UniProtKB/Swiss-Prot:VAR_043837,OMIM:601011.0011
# ClinGen:CA254437,UniProtKB/Swiss-Prot:VAR_043825,OMIM:601011.0009
# ClinGen:CA254443,UniProtKB/Swiss-Prot:VAR_043835,OMIM:601011.0012
# ClinGen:CA254473,UniProtKB/Swiss-Prot:VAR_043821,OMIM:601011.0017
# ClinGen:CA119653,UniProtKB/Swiss-Prot:VAR_043826,OMIM:601011.0018
# ClinGen:CA254496,UniProtKB/Swiss-Prot:VAR_043830,OMIM:601011.0027
# ClinGen:CA256584,UniProtKB/Swiss-Prot:VAR_010111,OMIM:182389.0001
# ClinGen:CA256587,UniProtKB/Swiss-Prot:VAR_010110,OMIM:182389.0002
# ClinGen:CA256596,UniProtKB/Swiss-Prot:VAR_014273,OMIM:182389.0005
# ClinGen:CA256599,UniProtKB/Swiss-Prot:VAR_014270,OMIM:182389.0006
# ClinGen:CA281911,UniProtKB/Swiss-Prot:VAR_014268,OMIM:182389.0009
# ClinGen:CA256602,UniProtKB/Swiss-Prot:VAR_014271,OMIM:182389.0010
# ClinGen:CA256611,UniProtKB/Swiss-Prot:VAR_029717,OMIM:182389.0013
# ClinGen:CA256620,UniProtKB/Swiss-Prot:VAR_057997,OMIM:182389.0021
# ClinGen:CA129599,UniProtKB/Swiss-Prot:VAR_065236,OMIM:613113.0045
# ClinGen:CA129841,UniProtKB/Swiss-Prot:VAR_068224,OMIM:607211.0001
# ClinGen:CA218986,UniProtKB/Swiss-Prot:VAR_007284
# ClinGen:CA218994,UniProtKB/Swiss-Prot:VAR_054208
# ClinGen:CA218996,UniProtKB/Swiss-Prot:VAR_054209
# ClinGen:CA219014,UniProtKB/Swiss-Prot:VAR_054171
# ClinGen:CA219018,UniProtKB/Swiss-Prot:VAR_054172
# ClinGen:CA219022,UniProtKB/Swiss-Prot:VAR_054174
# ClinGen:CA219024,UniProtKB/Swiss-Prot:VAR_054175
# UniProtKB/Swiss-Prot:VAR_007255,ClinGen:CA219026
# ClinGen:CA219044,UniProtKB/Swiss-Prot:VAR_007263
# ClinGen:CA219046,UniProtKB/Swiss-Prot:VAR_054182
# ClinGen:CA219052,UniProtKB/Swiss-Prot:VAR_007268
# ClinGen:CA219054,UniProtKB/Swiss-Prot:VAR_054186
# ClinGen:CA219056,UniProtKB/Swiss-Prot:VAR_007270
# ClinGen:CA219060,UniProtKB/Swiss-Prot:VAR_054190
# ClinGen:CA219062,UniProtKB/Swiss-Prot:VAR_054192
# ClinGen:CA219064,UniProtKB/Swiss-Prot:VAR_054194
# ClinGen:CA219070,UniProtKB/Swiss-Prot:VAR_054196
# ClinGen:CA219080,UniProtKB/Swiss-Prot:VAR_067417
# ClinGen:CA219082,UniProtKB/Swiss-Prot:VAR_054199
# ClinGen:CA219084,UniProtKB/Swiss-Prot:VAR_054200
# ClinGen:CA219086,UniProtKB/Swiss-Prot:VAR_007275
# ClinGen:CA219188,UniProtKB/Swiss-Prot:VAR_065662
# ClinGen:CA219267,UniProtKB/Swiss-Prot:VAR_068835
# ClinGen:CA219300,UniProtKB/Swiss-Prot:VAR_025588
# ClinGen:CA219316,UniProtKB/Swiss-Prot:VAR_066395
# ClinGen:CA219319,UniProtKB/Swiss-Prot:VAR_003184
# ClinGen:CA219322,UniProtKB/Swiss-Prot:VAR_025592
# ClinGen:CA219325,UniProtKB/Swiss-Prot:VAR_025593
# ClinGen:CA219331,UniProtKB/Swiss-Prot:VAR_025595
# ClinGen:CA219334,UniProtKB/Swiss-Prot:VAR_032113
# ClinGen:CA219337,UniProtKB/Swiss-Prot:VAR_025581
# ClinGen:CA219343,UniProtKB/Swiss-Prot:VAR_025582
# ClinGen:CA219352,UniProtKB/Swiss-Prot:VAR_025584
# ClinGen:CA219364,UniProtKB/Swiss-Prot:VAR_025599
# ClinGen:CA152091,UniProtKB/Swiss-Prot:VAR_014459
# ClinGen:CA152094,UniProtKB/Swiss-Prot:VAR_043828
# ClinGen:CA147061,UniProtKB/Swiss-Prot:VAR_014462
# ClinGen:CA266053,UniProtKB/Swiss-Prot:VAR_043838
# ClinGen:CA266071,UniProtKB/Swiss-Prot:VAR_043820
# ClinGen:CA266080,UniProtKB/Swiss-Prot:VAR_043822
# ClinGen:CA284895,UniProtKB/Swiss-Prot:VAR_064304
# ClinGen:CA284910,UniProtKB/Swiss-Prot:VAR_029683
# ClinGen:CA284913,UniProtKB/Swiss-Prot:VAR_064251
# ClinGen:CA284925,UniProtKB/Swiss-Prot:VAR_043360
# ClinGen:CA284928,UniProtKB/Swiss-Prot:VAR_029693
# ClinGen:CA284931,UniProtKB/Swiss-Prot:VAR_064311
# ClinGen:CA284934,UniProtKB/Swiss-Prot:VAR_043362
# ClinGen:CA284940,UniProtKB/Swiss-Prot:VAR_029699
# ClinGen:CA284943,UniProtKB/Swiss-Prot:VAR_064260
# ClinGen:CA284949,UniProtKB/Swiss-Prot:VAR_064313
# ClinGen:CA284958,UniProtKB/Swiss-Prot:VAR_064348
# ClinGen:CA284961,UniProtKB/Swiss-Prot:VAR_064315
# ClinGen:CA284976,UniProtKB/Swiss-Prot:VAR_064265
# ClinGen:CA284979,UniProtKB/Swiss-Prot:VAR_064319
# ClinGen:CA145250,UniProtKB/Swiss-Prot:VAR_043368
# ClinGen:CA284982,UniProtKB/Swiss-Prot:VAR_064320
# ClinGen:CA145253,UniProtKB/Swiss-Prot:VAR_043369
# ClinGen:CA284991,UniProtKB/Swiss-Prot:VAR_064269
# ClinGen:CA145256,UniProtKB/Swiss-Prot:VAR_043370
# ClinGen:CA285006,UniProtKB/Swiss-Prot:VAR_064327
# ClinGen:CA285012,UniProtKB/Swiss-Prot:VAR_064328
# ClinGen:CA285015,UniProtKB/Swiss-Prot:VAR_064329
# ClinGen:CA285018,UniProtKB/Swiss-Prot:VAR_029720
# ClinGen:CA285021,UniProtKB/Swiss-Prot:VAR_064275
# ClinGen:CA285024,UniProtKB/Swiss-Prot:VAR_064345
# ClinGen:CA285030,UniProtKB/Swiss-Prot:VAR_064351
# ClinGen:CA219773,UniProtKB/Swiss-Prot:VAR_043371
# ClinGen:CA266101,UniProtKB/Swiss-Prot:VAR_029675
# ClinGen:CA266104,UniProtKB/Swiss-Prot:VAR_064306
# ClinGen:CA285072,UniProtKB/Swiss-Prot:VAR_064247
# ClinGen:CA273369,UniProtKB/Swiss-Prot:VAR_029678
# ClinGen:CA285087,UniProtKB/Swiss-Prot:VAR_064248
# ClinGen:CA285093,UniProtKB/Swiss-Prot:VAR_029681
# ClinGen:CA269785,UniProtKB/Swiss-Prot:VAR_029682
# ClinGen:CA285099,UniProtKB/Swiss-Prot:VAR_064252
# ClinGen:CA285102,UniProtKB/Swiss-Prot:VAR_064253
# ClinGen:CA285105,UniProtKB/Swiss-Prot:VAR_029684
# ClinGen:CA285111,UniProtKB/Swiss-Prot:VAR_029686
# ClinGen:CA266107,UniProtKB/Swiss-Prot:VAR_029690
# ClinGen:CA285129,UniProtKB/Swiss-Prot:VAR_064254
# ClinGen:CA285141,UniProtKB/Swiss-Prot:VAR_064255
# ClinGen:CA285150,UniProtKB/Swiss-Prot:VAR_064256
# ClinGen:CA285162,UniProtKB/Swiss-Prot:VAR_064261
# ClinGen:CA285165,UniProtKB/Swiss-Prot:VAR_029701
# ClinGen:CA285180,UniProtKB/Swiss-Prot:VAR_064266
# ClinGen:CA285189,UniProtKB/Swiss-Prot:VAR_029708
# ClinGen:CA266117,UniProtKB/Swiss-Prot:VAR_029709
# ClinGen:CA285192,UniProtKB/Swiss-Prot:VAR_064270
# ClinGen:CA266120,UniProtKB/Swiss-Prot:VAR_029715
# ClinGen:CA285207,UniProtKB/Swiss-Prot:VAR_029716
# ClinGen:CA285234,UniProtKB/Swiss-Prot:VAR_064274
# ClinGen:CA285237,UniProtKB/Swiss-Prot:VAR_029723
# ClinGen:CA206668,UniProtKB/Swiss-Prot:VAR_029724
# ClinGen:CA266129,UniProtKB/Swiss-Prot:VAR_029727
# ClinGen:CA285249,UniProtKB/Swiss-Prot:VAR_029729
# ClinGen:CA266187,UniProtKB/Swiss-Prot:VAR_009603

# %%
import pandas as pd
import os
def if_positive_or_negative(string_list):
    label=[]
    for string in string_list:
        if string in ['Pathogenic', 
                    'Pathogenic/Likely pathogenic', 
                    'probable-pathogenic',
                    'Likely pathogenic', 
                    'pathologic', 
                    'pathogenic',
                    'likely pathogenic',
                    'Pathogenic/Likely pathogenic/Established risk allele',
                    'likely pathogenic - adrenal pheochromocytoma',
                    'Pathogenic/Pathogenic, low penetrance',
                    'Pathogenic, low penetrance']:
            label.append(1)
        elif string in ['Benign',
                    'Likely benign',
                    'Likely Benign',
                    'Benign/Likely benign',
                    'non-pathogenic', 
                    'benign', 'probable-non-pathogenic', 'Likely Benign', 'probably not pathogenic',
        ]:
            label.append(-1)

        else: label.append(0)
    return label



import requests
import json
import re
def find_fasta_refseq(refseqID):
    url='https://rest.uniprot.org/uniprotkb/search?query=%s'%refseqID
    cnt=json.loads(requests.get(url).text)
    try:
        assert re.search('uniprot',cnt.get("results")[0].get("entryType"),re.IGNORECASE)
        return cnt["results"][0]['primaryAccession']
    except:
        print('Error found in '+url)
        return 'Error found in '+url

def get_uniprot_from_name(name):
    try:
        refseq=re.match(r'\S*?(?=[\(:])',name).group(0)
        uniprot=find_fasta_refseq(refseq)

    except:
        refseq='Error Finding Refseq'
        print('Error Finding Refseq')
        uniprot=find_fasta_refseq(refseq)
    return uniprot 

def exlude_synonymous(name):
    #"NM_017813.5(BPNT2):c.228C>A (p.Arg76=)"
    return bool(re.match(r'.*(\(p\.[a-zA-Z0-9]*=\)).*',name))

def get_refseq_from_name(name):
    try:
        refseq=re.match(r'\S*?(?=[\(:])',name).group(0)

    except:
        refseq='Error Finding Refseq'
        print('Error Finding Refseq')
    return refseq 


data_path='/home/grads/z/zshuying/Documents/shuying/ppi_mutation/data'
f=pd.read_csv(os.path.join(data_path,'clinvar','variant_summary_2022-02.txt'),sep='\t')

f['label']=if_positive_or_negative(f['ClinicalSignificance'])

keep_cols=['#AlleleID', 'Type', 'Name','label', 'ClinicalSignificance', 'ClinSigSimple', 'ReviewStatus', 'OtherIDs', 'LastEvaluated', 'RS# (dbSNP)',
    'nsv/esv (dbVar)', 'RCVaccession']
keep_conditions=(f['Type']=='single nucleotide variant') &\
            (['no assertion' not in item for item in f['ReviewStatus'].tolist()]) &\
            (['p' in item for item in f['Name'].tolist()]) &\
            (f['label']!=0) &\
            ([bool(exlude_synonymous(name))==False for name in f['Name'].tolist()])
f_simple=f[keep_conditions][keep_cols]
# Out:
# /tmp/ipykernel_182771/2711039865.py:71: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   f=pd.read_csv(os.path.join(data_path,'clinvar','variant_summary_2022-02.txt'),sep='\t')

# %%
keep_conditions=(f['Type']=='single nucleotide variant') &\
            (['no assertion' not in item for item in f['ReviewStatus'].tolist()]) &\
            (['p' in item for item in f['Name'].tolist()]) &\
            (f['label']!=0) &\
            ([bool(exlude_synonymous(name))==False for name in f['Name'].tolist()])
f_simple=f[keep_conditions][keep_cols]
